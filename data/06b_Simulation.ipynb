# %%
# %matplotlib widget

from ipywidgets import interact, interactive, fixed, interact_manual
import matplotlib.pyplot as plt


def plotten(Startwert, Endwert, Schrittweite): 
    plt.clf()
    X = []
    Y = []
    xPunkte=[2,4,6,8]
    yPunkte=[22,24,26,28]
    plt.plot(xPunkte,yPunkte,'xr')
    for x in range(Startwert, Endwert, Schrittweite):
        X.append(x)
        Y.append(20 + x) 
    plt.plot(X,Y, 'bo')
    plt.xlabel('x-Werte')
    plt.ylabel('y-Werte')
    plt.ylim(20,29)
    plt.xlim(1,9)

a=interactive(plotten, Startwert=(-2,5), Endwert=(5,9), Schrittweite=(1,5))
display(a)
# Out:
# interactive(children=(IntSlider(value=1, description='Startwert', max=5, min=-2), IntSlider(value=7, descripti…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
